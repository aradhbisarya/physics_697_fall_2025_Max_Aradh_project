# %%
import numpy as np

m = 1
w = 1
N = 24
F = 1
C = 3

class term:
    def __init__(self):
        self.coeff = 1
        self.ops = []
    def __mul__(self, other):
        result = term()
        result.coeff = self.coeff * other.coeff
        result.ops = self.ops + other.ops
        return result

class sop_state:
    def __init__(self,):
        self.coeff = 0
        self.terms = []
    def __mul__(self, other):
        result = sop_state()
        result.coeff = self.coeff * other.coeff
        for term1 in self.terms:
            for term2 in other.terms:
                result.terms.append(term1*term2)
        return result

def l(n,i):
    return ((n-1)*F*C) + i - 1

def Q_ij(i,j,n):
    result = term()
    result.coeff = 1
    result.ops.append(('Q', l(n,i), l(n,j)))
    return result

def Q(i,n,m):
    result = sop_state()
    result.coeff = 1
    result.terms.append(Q_ij(i,j,n))
    return result
H_electric = sop_state()
H_electric.coeff = 1

# %%
r = 1.75/2000
import numpy as np
print(4/3*np.pi*r**3, "m^3")
print(str(4/3*np.pi*r**3*1e6) + " cm^3")
print(str(4/3*np.pi*r**3*1e9) + " mm^3")
rho = 7.950
print(str(4/3*np.pi*r**3*rho*1000*1e6) + " g")
print(str(4/3*np.pi*r**3*rho*1e3) + " kg")
# Out:
# 2.806162187972133e-09 m^3
# 0.002806162187972133 cm^3
# 2.806162187972133 mm^3
# 22.308989394378457 g
# 2.2308989394378458e-05 kg

# %%
((0.995+0.943+0.983)/3 - 1.49)/1.49 * 100
# Out:
# -34.65324384787473

# %%
0.00204/2.04e-7
# Out:
# 10000.0

# %%
Random = [0.04554104762484048, -0.39962507785166684, 0.31784280892454475, -0.3402633526553846, -0.21347893959531472, 0.22020662667319155]
Initial = [0.05748267450442515, 0.0010416977669512135, 0.00012748151136901203, 0.00015978837592750284, 0.0027976795419701337, -0.06160932197335117]

# %%
import matplotlib.pyplot as plt
plt.plot(Random, 'r.',label='Random')
plt.plot(Initial,'k.', label='Minimized')
plt.legend()
plt.xlabel('Site')
plt.ylabel('Number operator value')
plt.title('Number operator values for Random and Minimized states')
# Out:
# Text(0.5, 1.0, 'Number operator values for Random and Minimized states')
